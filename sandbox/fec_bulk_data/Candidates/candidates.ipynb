# %%
import pandas as pd
import requests
import datetime
import zipfile
import os
import numpy as np

# %% [markdown]
# ## Programmatically downloading zipped file of Candidates running in the 2024 election cycle.

# %% [markdown]
# ### Step 1. Create the directories ./zipped and ./unzipped

# %%
zip_path = "./zipped/"
unzipped_path = "./unzipped/"

if not os.path.exists(zip_path):
    os.makedirs(zip_path)

if not os.path.exists(unzipped_path):
    os.makedirs(unzipped_path)

# %% [markdown]
# ### Step 2. Download the header file.

# %%
candidate_header_url = "https://www.fec.gov/files/bulk-downloads/data_dictionaries/cn_header_file.csv"
header_req = requests.get(candidate_header_url)

header_output = "./candidate_header24.csv"

with open(header_output, 'wb') as header_file:
    header_file.write(header_req.content)

print("Candidate header file added!")
# Out:
# Candidate header file added!

# %% [markdown]
# ### Step 3. Download the Candidate Zip file.

# %%
cn_url = "https://www.fec.gov/files/bulk-downloads/2024/cn24.zip"
cn_req = requests.get(cn_url)

current_date = datetime.datetime.now()
current_date_fmt = current_date.strftime("%Y-%m-%d")

cn_path = f"./zipped/cn_2024_{current_date_fmt}.zip"

with open(cn_path, "wb") as cn_file:
    cn_file.write(cn_req.content)

print(f"File succefully added to {cn_path} ")
# Out:
# File succefully added to ./zipped/cn_2024_2024-02-06.zip

# %% [markdown]
# #### Step 4. Extact all files to ./unzipped.

# %%
extract_path = f"./unzipped/cn24_{current_date_fmt}/"
with zipfile.ZipFile(cn_path) as extract_zip:
    extract_zip.extractall(extract_path)

print(f"Files extracted to path: {extract_path}")
# Out:
# Files extracted to path: ./unzipped/cn24_2024-02-06/

# %% [markdown]
# ### Step 4. Convert to .csv and add header to file.

# %%
cn_header = pd.read_csv("./candidate_header24.csv")
# path = ""
cn_df = pd.read_csv(extract_path + "cn.txt", sep="|", names=cn_header.columns)

display(cn_df.head(n=10))
print(f"Total number of Candidates recorded: {len(cn_df)}")
# Out:
#      CAND_ID                  CAND_NAME CAND_PTY_AFFILIATION  \
# 0  H0AK00105               LAMB, THOMAS                  NNE
# 1  H0AL01055        CARL, JERRY LEE, JR                  REP
# 2  H0AL01097            AVERHART, JAMES                  DEM
# 3  H0AL02087               ROBY, MARTHA                  REP
# 4  H0AL02137             DISMUKES, WILL                  REP
# 5  H0AL02160  BROWN, THOMAS WILLIAM JR.                  REP
# 6  H0AL02202       HARVEY-HALL, PHYLLIS                  DEM
# 7  H0AL03192           THOMPSON, HANNAH                  DEM
# 8  H0AL05049  CRAMER, ROBERT E "BUD" JR                  DEM
# 9  H0AL05163                 BROOKS, MO                  REP
#
#    CAND_ELECTION_YR CAND_OFFICE_ST CAND_OFFICE  CAND_OFFICE_DISTRICT CAND_ICI  \
# 0              2020             AK           H                   0.0        C
# 1              2024             AL           H                   1.0        I
# 2              2024             AL           H                   2.0        C
# 3              2020             AL           H                   2.0        I
# 4              2020             AL           H                   2.0        O
# 5              2020             AL           H                   2.0        O
# 6              2024             AL           H                   2.0        C
# 7              2020             AL           H                   3.0        C
# 8              2008             AL           H                   5.0        I
# 9              2022             AL           H                   5.0        I
#
#   CAND_STATUS   CAND_PCC                CAND_ST1 CAND_ST2       CAND_CITY  \
# 0           N  C00607515  1861 W LAKE LUCILLE DR      NaN         WASILLA
# 1           C  C00697789           PO BOX 852138      NaN          MOBILE
# 2           C  C00708867       811 SPRINGHILL AV      NaN          MOBILE
# 3           P  C00462143                     NaN      NaN      MONTGOMERY
# 4           P  C00714337          PO BOX 6811188      NaN      PRATTVILLE
# 5           P  C00723478        110 RIVERVIEW DR      NaN          NEWTON
# 6           C  C00728873          P.O. BOX 11564      NaN      MONTGOMERY
# 7           N  C00681452         2181 N BROADWAY      NaN  ALEXANDER CITY
# 8           P  C00239038             PO BOX 2621      NaN      HUNTSVILLE
# 9           P  C00464149        7610 FOXFIRE DR.      NaN      HUNTSVILLE
#
#   CAND_ST  CAND_ZIP
# 0      AK   99654.0
# 1      AL   36685.0
# 2      AL   36602.0
# 3     NaN       NaN
# 4      AL   36068.0
# 5      AL   36352.0
# 6      AL   36111.0
# 7      AL   35010.0
# 8      AL   35804.0
# 9      AL   35802.0
# Total number of Candidates recorded: 8390

# %%
print(cn_df.dtypes)
# Out:
# CAND_ID                  object
# CAND_NAME                object
# CAND_PTY_AFFILIATION     object
# CAND_ELECTION_YR          int64
# CAND_OFFICE_ST           object
# CAND_OFFICE              object
# CAND_OFFICE_DISTRICT    float64
# CAND_ICI                 object
# CAND_STATUS              object
# CAND_PCC                 object
# CAND_ST1                 object
# CAND_ST2                 object
# CAND_CITY                object
# CAND_ST                  object
# CAND_ZIP                float64
# dtype: object

# %% [markdown]
# ### Step 5. Minor data cleaning.

# %%
cn_df["CAND_OFFICE_DISTRICT"] = cn_df["CAND_OFFICE_DISTRICT"].fillna(0) #Fills all NaN with 0
cn_df["CAND_OFFICE_DISTRICT"] = cn_df["CAND_OFFICE_DISTRICT"].astype(int)

# cn_df["CAND_ZIP"] = cn_df["CAND_ZIP"].fillna(0)
# cn_df["CAND_ZIP"] = cn_df["CAND_ZIP"].astype(int) #To remove zero padding
cn_df["CAND_ZIP"] = cn_df["CAND_ZIP"].astype(str) #To adhere to ERD type
cn_df["CAND_ZIP"] = cn_df["CAND_ZIP"].str.split('.').str[0]
cn_df.loc[cn_df["CAND_ZIP"] == 'nan00', 'CAND_ZIP'] = np.nan #The line above results in nan becoming "nan00". This converts them to proper NaN values

display(cn_df.head(n=10))
# Out:
#      CAND_ID                  CAND_NAME CAND_PTY_AFFILIATION  \
# 0  H0AK00105               LAMB, THOMAS                  NNE
# 1  H0AL01055        CARL, JERRY LEE, JR                  REP
# 2  H0AL01097            AVERHART, JAMES                  DEM
# 3  H0AL02087               ROBY, MARTHA                  REP
# 4  H0AL02137             DISMUKES, WILL                  REP
# 5  H0AL02160  BROWN, THOMAS WILLIAM JR.                  REP
# 6  H0AL02202       HARVEY-HALL, PHYLLIS                  DEM
# 7  H0AL03192           THOMPSON, HANNAH                  DEM
# 8  H0AL05049  CRAMER, ROBERT E "BUD" JR                  DEM
# 9  H0AL05163                 BROOKS, MO                  REP
#
#    CAND_ELECTION_YR CAND_OFFICE_ST CAND_OFFICE  CAND_OFFICE_DISTRICT CAND_ICI  \
# 0              2020             AK           H                     0        C
# 1              2024             AL           H                     1        I
# 2              2024             AL           H                     2        C
# 3              2020             AL           H                     2        I
# 4              2020             AL           H                     2        O
# 5              2020             AL           H                     2        O
# 6              2024             AL           H                     2        C
# 7              2020             AL           H                     3        C
# 8              2008             AL           H                     5        I
# 9              2022             AL           H                     5        I
#
#   CAND_STATUS   CAND_PCC                CAND_ST1 CAND_ST2       CAND_CITY  \
# 0           N  C00607515  1861 W LAKE LUCILLE DR      NaN         WASILLA
# 1           C  C00697789           PO BOX 852138      NaN          MOBILE
# 2           C  C00708867       811 SPRINGHILL AV      NaN          MOBILE
# 3           P  C00462143                     NaN      NaN      MONTGOMERY
# 4           P  C00714337          PO BOX 6811188      NaN      PRATTVILLE
# 5           P  C00723478        110 RIVERVIEW DR      NaN          NEWTON
# 6           C  C00728873          P.O. BOX 11564      NaN      MONTGOMERY
# 7           N  C00681452         2181 N BROADWAY      NaN  ALEXANDER CITY
# 8           P  C00239038             PO BOX 2621      NaN      HUNTSVILLE
# 9           P  C00464149        7610 FOXFIRE DR.      NaN      HUNTSVILLE
#
#   CAND_ST CAND_ZIP
# 0      AK    99654
# 1      AL    36685
# 2      AL    36602
# 3     NaN      NaN
# 4      AL    36068
# 5      AL    36352
# 6      AL    36111
# 7      AL    35010
# 8      AL    35804
# 9      AL    35802

# %%
source_path = f"../source/cn24_{current_date_fmt}.csv"
cn_df.to_csv(source_path, sep=",", index=False)
print(f"Source file for CCL has been created in {source_path}.")
# Out:
# Source file for CCL has been created in ../source/cn24_2024-02-06.csv.

# %%
final_csv = pd.read_csv(f"../source/cn24_{current_date_fmt}.csv", sep=",")
display(final_csv.head(n=20))
# Out:
#       CAND_ID                  CAND_NAME CAND_PTY_AFFILIATION  \
# 0   H0AK00105               LAMB, THOMAS                  NNE
# 1   H0AL01055        CARL, JERRY LEE, JR                  REP
# 2   H0AL01097            AVERHART, JAMES                  DEM
# 3   H0AL02087               ROBY, MARTHA                  REP
# 4   H0AL02137             DISMUKES, WILL                  REP
# 5   H0AL02160  BROWN, THOMAS WILLIAM JR.                  REP
# 6   H0AL02202       HARVEY-HALL, PHYLLIS                  DEM
# 7   H0AL03192           THOMPSON, HANNAH                  DEM
# 8   H0AL05049  CRAMER, ROBERT E "BUD" JR                  DEM
# 9   H0AL05163                 BROOKS, MO                  REP
# 10  H0AL06104         ALLEN, ANDERS POPE                  REP
# 11  H0AL06112  PELLEGRINO, KAYNEN BRYANT                  NPA
# 12  H0AL07086           SEWELL, TERRI A.                  DEM
# 13  H0AL07193  STOKES, CAMRON DEVIN HON.                  DEM
# 14  H0AR01083   CRAWFORD, ERIC ALAN RICK                  REP
# 15  H0AR01109               CAUSEY, CHAD                  DEM
# 16  H0AR01125         SMITH, PRINCELLA D                  REP
# 17  H0AR03030    WHITAKER, DAVID JEFFREY                  DEM
# 18  H0AR03055  WOMACK, STEPHEN A THE HON                  REP
# 19  H0AR04095             GILBERT, FRANK                  LIB
#
#     CAND_ELECTION_YR CAND_OFFICE_ST CAND_OFFICE  CAND_OFFICE_DISTRICT  \
# 0               2020             AK           H                     0
# 1               2024             AL           H                     1
# 2               2024             AL           H                     2
# 3               2020             AL           H                     2
# 4               2020             AL           H                     2
# 5               2020             AL           H                     2
# 6               2024             AL           H                     2
# 7               2020             AL           H                     3
# 8               2008             AL           H                     5
# 9               2022             AL           H                     5
# 10              2020             AL           H                     6
# 11              2020             AL           H                     6
# 12              2024             AL           H                     7
# 13              2020             AL           H                     7
# 14              2024             AR           H                     1
# 15              2010             AR           H                     1
# 16              2010             AR           H                     1
# 17              2010             AR           H                     3
# 18              2024             AR           H                     3
# 19              2020             AR           H                     4
#
#    CAND_ICI CAND_STATUS   CAND_PCC                CAND_ST1 CAND_ST2  \
# 0         C           N  C00607515  1861 W LAKE LUCILLE DR      NaN
# 1         I           C  C00697789           PO BOX 852138      NaN
# 2         C           C  C00708867       811 SPRINGHILL AV      NaN
# 3         I           P  C00462143                     NaN      NaN
# 4         O           P  C00714337          PO BOX 6811188      NaN
# 5         O           P  C00723478        110 RIVERVIEW DR      NaN
# 6         C           C  C00728873          P.O. BOX 11564      NaN
# 7         C           N  C00681452         2181 N BROADWAY      NaN
# 8         I           P  C00239038             PO BOX 2621      NaN
# 9         I           P  C00464149        7610 FOXFIRE DR.      NaN
# 10        C           N  C00681213         123 KATY CIRCLE      NaN
# 11        C           N  C00696765       160 CARRINGTON LN      NaN
# 12        I           C  C00458976             PO BOX 1964      NaN
# 13        C           N  C00723601       5844 EAGLE CIRCLE      NaN
# 14        I           C  C00462374               34 CR 455      NaN
# 15        O           P  C00475384     205 SOUTH MAIN #203      NaN
# 16        O           P  C00480905      2000 WYNRIDGE COVE      NaN
# 17        O           P  C00468033              PO BOX 957      NaN
# 18        I           C  C00477745         91 WOODRIDGE LN      NaN
# 19        C           N  C00740530         1825 BUTRAM RD.      NaN
#
#          CAND_CITY CAND_ST     CAND_ZIP
# 0          WASILLA      AK      99654.0
# 1           MOBILE      AL      36685.0
# 2           MOBILE      AL      36602.0
# 3       MONTGOMERY     NaN          NaN
# 4       PRATTVILLE      AL      36068.0
# 5           NEWTON      AL      36352.0
# 6       MONTGOMERY      AL      36111.0
# 7   ALEXANDER CITY      AL      35010.0
# 8       HUNTSVILLE      AL      35804.0
# 9       HUNTSVILLE      AL      35802.0
# 10      BIRMINGHAM      AL      35242.0
# 11          CALERA      AL      35040.0
# 12      BIRMINGHAM      AL      35201.0
# 13      MONTGOMERY      AL      36116.0
# 14       JONESBORO      AR      72404.0
# 15       JONESBORO      AR      72401.0
# 16           WYNNE      AR      72396.0
# 17    FAYETTEVILLE      AR  727020957.0
# 18          ROGERS      AR  727563078.0
# 19      WHITE HALL      AR      71602.0
