# %%
import pandas as pd
import requests
import datetime
import zipfile

# %% [markdown]
# ## Programmatically downloading zipped file of Individual Contributions
# For now, I am storing all the files locally but, in production I will store these files in an S3 bucket.

# %% [markdown]
# ### Step 1. Download the zipped file from FEC website and place it in the /zipped folder.

# %%
url = "http://www.fec.gov/files/bulk-downloads/2024/indiv24.zip" #Link to zip file containing all individual contritibutions for the 2024 election cycle
current_date = datetime.datetime.now()
current_date_fmt = current_date.strftime("%Y-%m-%d")

output_path = f"./zipped/ic24_{current_date_fmt}.zip"
file_req = requests.get(url)

with open(output_path,'wb') as output_file:
    output_file.write(file_req.content)

print(f"File succefully added to {output_path} ")
# Out:
# File succefully added to ./zipped/ic24_2024-02-01.zip

# %% [markdown]
# ### Step 2. Extract all the contents of the zipped file into the "/unzipped/ic24_{Current Date}" folder.

# %%
extract_path = f"./unzipped/ic24_{current_date_fmt}/"
with zipfile.ZipFile(output_path) as extract_zip:
    extract_zip.extractall(extract_path)

print(f"Files extracted to path: {extract_path}")
# Out:
# Files extracted to path: ./unzipped/ic24_2024-02-01/

# %% [markdown]
# ### Step 3. Add the column headers to the individual contribution file and convert the .txt file to a .csv.

# %%
header_df = pd.read_csv("./indiv_header_file.csv")
# print(header_df)
df = pd.read_csv(extract_path + "itcont.txt", sep="|", names=header_df.columns)
display(df.head(n=10))
print(f"Total number of individual contributions recorded: {len(df)}")
# Out:
# C:\Users\ayoku\AppData\Local\Temp\ipykernel_28984\3596964457.py:3: DtypeWarning: Columns (10,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(extract_path + "itcont.txt", sep="|", names=header_df.columns)
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI           IMAGE_NUM  \
# 0  C00817940         T    TER               P  202301239574900260
# 1  C00817940         T    TER               P  202301239574900260
# 2  C00817940         T    TER               P  202301239574900260
# 3  C00817940         T    TER               P  202301239574900261
# 4  C00817940         T    TER               P  202301239574900261
# 5  C00817940         T    TER               P  202301239574900261
# 6  C00817940         T    TER               P  202301239574900262
# 7  C00815316         T    TER               P  202301239574918787
# 8  C00806752         T    TER           P2022  202211189546828121
# 9  C00806752         T    TER           P2022  202211189546828120
#
#   TRANSACTION_TP ENTITY_TP                    NAME         CITY STATE  ...  \
# 0            22Y       IND             DUFF, JAMES  LOS ANGELES    CA  ...
# 1            22Y       IND         ROTHMAN, ANDREW  CULVER CITY    CA  ...
# 2            22Y       IND          PELLETT, CLARK      CHICAGO    IL  ...
# 3            22Y       IND         DISNEY, TIMOTHY       ENCINO    CA  ...
# 4            22Y       IND            TRONE, DAVID      POTOMAC    MD  ...
# 5            22Y       IND    MISCIKOWSKI, CYNTHIA  LOS ANGELES    CA  ...
# 6            22Y       IND              HOOD, JOHN      DEL MAR    CA  ...
# 7            20Y       IND          DANFORTH, JOHN     NEW YORK    NY  ...
# 8             15       CAN            STEEL, DIANE    LAS VEGAS    NV  ...
# 9             15       ORG  AURELIA ARNOLD ROBERTS    LAS VEGAS    NV  ...
#
#   EMPLOYER OCCUPATION TRANSACTION_DT  TRANSACTION_AMT  OTHER_ID      TRAN_ID  \
# 0      NaN        NaN        1192023              800       NaN    500241283
# 1      NaN        NaN        1192023              250       NaN    500241284
# 2      NaN        NaN        1202023              345       NaN    500241285
# 3      NaN        NaN        1192023              615       NaN    500241286
# 4      NaN        NaN        1192023             5000       NaN    500241287
# 5      NaN        NaN        1192023             5000       NaN    500241288
# 6      NaN        NaN        1202023             5000       NaN    500241289
# 7      NaN        NaN        1232023           379827       NaN   SB28A.4281
# 8     NONE    RETIRED        6302022             7709       NaN  SA11AI.4337
# 9      NaN        NaN        4052022              580       NaN  SA11AI.4276
#
#   FILE_NUM  MEMO_CD MEMO_TEXT               SUB_ID
# 0  1678288      NaN       NaN  4012320231720334166
# 1  1678288      NaN       NaN  4012320231720334167
# 2  1678288      NaN       NaN  4012320231720334168
# 3  1678288      NaN       NaN  4012320231720334169
# 4  1678288      NaN       NaN  4012320231720334170
# 5  1678288      NaN       NaN  4012320231720334171
# 6  1678288      NaN       NaN  4012320231720334172
# 7  1678556      NaN       NaN  4012420231720406200
# 8  1661961      NaN       NaN  4120820221633698139
# 9  1661961      NaN       NaN  4120820221633698136
#
# [10 rows x 21 columns]
# Total number of individual contributions recorded: 9705390

# %% [markdown]
# ## Minor data cleaning

# %%
print(df.dtypes)
# Out:
# CMTE_ID            object
# AMNDT_IND          object
# RPT_TP             object
# TRANSACTION_PGI    object
# IMAGE_NUM           int64
# TRANSACTION_TP     object
# ENTITY_TP          object
# NAME               object
# CITY               object
# STATE              object
# ZIP_CODE           object
# EMPLOYER           object
# OCCUPATION         object
# TRANSACTION_DT      int64
# TRANSACTION_AMT     int64
# OTHER_ID           object
# TRAN_ID            object
# FILE_NUM            int64
# MEMO_CD            object
# MEMO_TEXT          object
# SUB_ID              int64
# dtype: object

# %% [markdown]
# The "TRANSATION_DT" is meant to have a DATETIME data type but, Pandas is reading that column as a integer. Let's fix that!

# %%
try:
    df["TRANSACTION_DT"] = pd.to_datetime(df["TRANSACTION_DT"], format="%m%d%Y", errors='raise')
    display(df["TRANSACTION_DT"].head(n=10))
except ValueError:
    pass
# Out:
# 0   2023-11-09
# 1   2023-11-09
# 2   2023-01-20
# 3   2023-11-09
# 4   2023-11-09
# 5   2023-11-09
# 6   2023-01-20
# 7   2023-12-03
# 8   2022-06-30
# 9   2022-04-05
# Name: TRANSACTION_DT, dtype: datetime64[ns]

# %%
print(df.dtypes)
# Out:
# CMTE_ID                    object
# AMNDT_IND                  object
# RPT_TP                     object
# TRANSACTION_PGI            object
# IMAGE_NUM                   int64
# TRANSACTION_TP             object
# ENTITY_TP                  object
# NAME                       object
# CITY                       object
# STATE                      object
# ZIP_CODE                   object
# EMPLOYER                   object
# OCCUPATION                 object
# TRANSACTION_DT     datetime64[ns]
# TRANSACTION_AMT             int64
# OTHER_ID                   object
# TRAN_ID                    object
# FILE_NUM                    int64
# MEMO_CD                    object
# MEMO_TEXT                  object
# SUB_ID                      int64
# dtype: object

# %% [markdown]
# That is all I had to change, on to making the final source file.

# %% [markdown]
# ## Creating a finalized source .csv

# %%
source_path = f"./source/ic_2024_{current_date_fmt}.csv"
df.to_csv(source_path, sep=",", index=False)
print(f"Source file for Individual Contributions has been created in {source_path}.")
# Out:
# Source file for Individual Contributions has been created in ./source/ic_2024_2024-02-01.csv.

# %%
final_csv = pd.read_csv("./source/ic_2024_2024-02-01.csv", sep=",")
display(final_csv.head(n=20))
# Out:
# C:\Users\ayoku\AppData\Local\Temp\ipykernel_28984\2389871573.py:1: DtypeWarning: Columns (10,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   final_csv = pd.read_csv("./source/ic_2024_2024-02-01.csv", sep=",")
#       CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI           IMAGE_NUM  \
# 0   C00817940         T    TER               P  202301239574900260
# 1   C00817940         T    TER               P  202301239574900260
# 2   C00817940         T    TER               P  202301239574900260
# 3   C00817940         T    TER               P  202301239574900261
# 4   C00817940         T    TER               P  202301239574900261
# 5   C00817940         T    TER               P  202301239574900261
# 6   C00817940         T    TER               P  202301239574900262
# 7   C00815316         T    TER               P  202301239574918787
# 8   C00806752         T    TER           P2022  202211189546828121
# 9   C00806752         T    TER           P2022  202211189546828120
# 10  C00806752         T    TER           P2022  202211189546828120
# 11  C00806752         T    TER           P2022  202211189546828120
# 12  C00796540         T    TER           P2022  202301139574688531
# 13  C00796540         T    TER           P2022  202301139574688531
# 14  C00796540         T    TER           G2022  202301139574688531
# 15  C00796540         T    TER           G2022  202301139574688532
# 16  C00806562         T    TER               P  202301249574939682
# 17  C00806372         T    TER           P2022  202301249574932524
# 18  C00790964         T    TER           P2022  202301249574942305
# 19  C00790964         T    TER           P2022  202301249574942305
#
#    TRANSACTION_TP ENTITY_TP                    NAME          CITY STATE  ...  \
# 0             22Y       IND             DUFF, JAMES   LOS ANGELES    CA  ...
# 1             22Y       IND         ROTHMAN, ANDREW   CULVER CITY    CA  ...
# 2             22Y       IND          PELLETT, CLARK       CHICAGO    IL  ...
# 3             22Y       IND         DISNEY, TIMOTHY        ENCINO    CA  ...
# 4             22Y       IND            TRONE, DAVID       POTOMAC    MD  ...
# 5             22Y       IND    MISCIKOWSKI, CYNTHIA   LOS ANGELES    CA  ...
# 6             22Y       IND              HOOD, JOHN       DEL MAR    CA  ...
# 7             20Y       IND          DANFORTH, JOHN      NEW YORK    NY  ...
# 8              15       CAN            STEEL, DIANE     LAS VEGAS    NV  ...
# 9              15       ORG  AURELIA ARNOLD ROBERTS     LAS VEGAS    NV  ...
# 10             15       ORG          JENNIFER HENRY     LAS VEGAS    NV  ...
# 11             15       IND              LAUB, BILL     LAS VEGAS    NV  ...
# 12            22Y       IND            ROSE, HAL M.      BROOKLYN    NY  ...
# 13            22Y       IND              ROSE, LISA      BROOKLYN    NY  ...
# 14            22Y       IND        ARONSON, BERNARD   TAKOMA PARK    MD  ...
# 15            22Y       IND         AIZER, ROSEMARY      NEW YORK    NY  ...
# 16             10       ORG          RED ROCK GROUP     SAN DIEGO    CA  ...
# 17            15C       CAN            SEGAL, DAVID    PROVIDENCE    RI  ...
# 18            15C       CAN     CASANOVA, MANUEL I.  NEW ROCHELLE    NY  ...
# 19            15C       CAN     CASANOVA, MANUEL I.  NEW ROCHELLE    NY  ...
#
#                                   EMPLOYER    OCCUPATION TRANSACTION_DT  \
# 0                                      NaN           NaN     2023-11-09
# 1                                      NaN           NaN     2023-11-09
# 2                                      NaN           NaN     2023-01-20
# 3                                      NaN           NaN     2023-11-09
# 4                                      NaN           NaN     2023-11-09
# 5                                      NaN           NaN     2023-11-09
# 6                                      NaN           NaN     2023-01-20
# 7                                      NaN           NaN     2023-12-03
# 8                                     NONE       RETIRED     2022-06-30
# 9                                      NaN           NaN     2022-04-05
# 10                                     NaN           NaN     2022-04-10
# 11                                    NONE       RETIRED     2022-04-11
# 12                                     NaN           NaN     2023-01-10
# 13                                     NaN           NaN     2023-01-10
# 14                                     NaN           NaN     2023-10-05
# 15                                     NaN           NaN     2023-10-05
# 16                                     NaN           NaN     2022-12-30
# 17                            NOT EMPLOYED  NOT EMPLOYED     2023-11-01
# 18  NEW YORK'S 16TH CONGRESSIONAL DISTRICT     CANDIDATE     2023-11-02
# 19  NEW YORK'S 16TH CONGRESSIONAL DISTRICT     CANDIDATE     2023-11-07
#
#    TRANSACTION_AMT   OTHER_ID      TRAN_ID FILE_NUM  MEMO_CD  \
# 0              800        NaN    500241283  1678288      NaN
# 1              250        NaN    500241284  1678288      NaN
# 2              345        NaN    500241285  1678288      NaN
# 3              615        NaN    500241286  1678288      NaN
# 4             5000        NaN    500241287  1678288      NaN
# 5             5000        NaN    500241288  1678288      NaN
# 6             5000        NaN    500241289  1678288      NaN
# 7           379827        NaN   SB28A.4281  1678556      NaN
# 8             7709        NaN  SA11AI.4337  1661961      NaN
# 9              580        NaN  SA11AI.4276  1661961      NaN
# 10             350        NaN  SA11AI.4282  1661961      NaN
# 11             480        NaN  SA11AI.4326  1661961      NaN
# 12             800        NaN    500209072  1676011      NaN
# 13             800        NaN    500209073  1676011      NaN
# 14            1000        NaN    500209074  1676011      NaN
# 15            1000        NaN    500209075  1676011      NaN
# 16            4329        NaN  SA11AI.4133  1679000      NaN
# 17           64427  H2RI02234      5448894  1678824      NaN
# 18            7500  H2NY16073      6024505  1679058      NaN
# 19            5000  H2NY16073      6024469  1679058      NaN
#
#                                             MEMO_TEXT               SUB_ID
# 0                                                 NaN  4012320231720334166
# 1                                                 NaN  4012320231720334167
# 2                                                 NaN  4012320231720334168
# 3                                                 NaN  4012320231720334169
# 4                                                 NaN  4012320231720334170
# 5                                                 NaN  4012320231720334171
# 6                                                 NaN  4012320231720334172
# 7                                                 NaN  4012420231720406200
# 8                                                 NaN  4120820221633698139
# 9                                                 NaN  4120820221633698136
# 10                                                NaN  4120820221633698137
# 11                                                NaN  4120820221633698138
# 12                                                NaN  4012120231720217822
# 13                                                NaN  4012120231720217823
# 14                                                NaN  4012120231720217824
# 15                                                NaN  4012120231720217825
# 16                                                NaN  4012520231720490563
# 17  IN-KIND: CANDIDATE LOAN FORGIVENESS - PERSONAL...  4012420231720393633
# 18          IN-KIND: LEGAL AND COMMUNICATION SERVICES  4012520231720493914
# 19    IN-KIND: ACCOUNTING, FEC, COMPLIANCE CONSULTING  4012520231720493915
#
# [20 rows x 21 columns]
