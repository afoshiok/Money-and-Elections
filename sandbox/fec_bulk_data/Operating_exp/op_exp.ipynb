# %%
import pandas as pd

# %%
header_file = "./oppexp_header_file.csv"
operating_exp_file = "./oppexp.txt"

operating_exp_header = pd.read_csv(header_file)
operating_exp_df = pd.read_csv(operating_exp_file,
                                       sep="|",
                                       names= operating_exp_header.columns,
                                       dtype= {"ZIP_CODE" : "object", "TRANSACTION_DT": "object", "ENTITY_TP": "object" }
                                       )

print(operating_exp_df.dtypes)
display(operating_exp_df.head(10))
# Out:
# C:\Users\ayoku\AppData\Local\Temp\ipykernel_27044\3680823692.py:5: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   operating_exp_df = pd.read_csv(operating_exp_file,
# CMTE_ID              object
# AMNDT_IND             int64
# RPT_YR               object
# RPT_TP                int64
# IMAGE_NUM            object
# LINE_NUM             object
# FORM_TP_CD           object
# SCHED_TP_CD          object
# NAME                 object
# CITY                 object
# STATE                object
# ZIP_CODE             object
# TRANSACTION_DT       object
# TRANSACTION_AMT      object
# TRANSACTION_PGI      object
# PURPOSE              object
# CATEGORY             object
# CATEGORY_DESC        object
# MEMO_CD              object
# MEMO_TEXT            object
# ENTITY_TP            object
# SUB_ID                int64
# FILE_NUM             object
# TRAN_ID              object
# BACK_REF_TRAN_ID    float64
# dtype: object
#           CMTE_ID  AMNDT_IND RPT_YR              RPT_TP IMAGE_NUM LINE_NUM  \
# C00794982       A       2023    TER  202301109574642828        17       F3
# C00794982       A       2023    TER  202301109574642828        17       F3
# C00794982       A       2023    TER  202301109574642828        17       F3
# C00819177       T       2023    TER  202301109574642263       21B      F3X
# C00819177       T       2023    TER  202301109574642263       21B      F3X
# C00819177       T       2023    TER  202301109574642263       21B      F3X
# C00758672       T       2023    TER  202301109574639559       21B      F3X
# C00800201       T       2023    TER  202301109574640445       21B      F3X
# C00800201       T       2023    TER  202301109574640445       21B      F3X
# C00806752       T       2023    TER  202211189546828125        17       F3
#
#           FORM_TP_CD                     SCHED_TP_CD           NAME CITY  ...  \
# C00794982         SB        BROGHAMER CONSULTING LLC        NEWPORT   KY  ...
# C00794982         SB                GRAUERT, MATTHEW     LOUISVILLE   KY  ...
# C00794982         SB                     TELLO, KURT     LOUISVILLE   KY  ...
# C00819177         SB              PURPURA, SALVATORE         MONROE   NC  ...
# C00819177         SB              PURPURA, SALVATORE         MONROE   NC  ...
# C00819177         SB                          INTUIT  MOUNTAIN VIEW   CA  ...
# C00758672         SB  CALIFORNIA FRANCHISE TAX BOARD    LOS ANGELES   CA  ...
# C00800201         SB       CAMPAIGN COMPLIANCE, INC.       MISSOULA   MT  ...
# C00800201         SB                     NGP VAN INC     WASHINGTON   DC  ...
# C00806752         SB                COSTCO WHOLESALE      HENDERSON   NV  ...
#
#           PURPOSE                                  CATEGORY CATEGORY_DESC  \
# C00794982     1.0  Administrative/Salary/Overhead Expenses            NaN
# C00794982     NaN                                       NaN           NaN
# C00794982     NaN                                       NaN           NaN
# C00819177     NaN                                       NaN           NaN
# C00819177     NaN                                       NaN           NaN
# C00819177     NaN                                       NaN             X
# C00758672     NaN                                       NaN           NaN
# C00800201     NaN                                       NaN           NaN
# C00800201     NaN                                       NaN           NaN
# C00806752     2.0                           Travel Expenses           NaN
#
#           MEMO_CD MEMO_TEXT            ENTITY_TP   SUB_ID  \
# C00794982     NaN       ORG  4012020231718627443  1675434
# C00794982     NaN       IND  4012020231718627444  1675434
# C00794982     NaN       IND  4012020231718627445  1675434
# C00819177     NaN       IND  4011820231709508274  1675412
# C00819177     NaN       IND  4011820231709508275  1675412
# C00819177     NaN       ORG  4011820231709508276  1675412
# C00758672     NaN       ORG  4011020231667596033  1675246
# C00800201     NaN       ORG  4011020231667599102  1675300
# C00800201     NaN       ORG  4011020231667599103  1675300
# C00806752     NaN       ORG  4120820221633731928  1661961
#
#                        FILE_NUM TRAN_ID BACK_REF_TRAN_ID
# C00794982  B99FBD49A0D1040A18CC     NaN              NaN
# C00794982  B1F8C934294B849A1AE7     NaN              NaN
# C00794982  B0C98B26380D94314B73     NaN              NaN
# C00819177             SB21.1323     NaN              NaN
# C00819177           SB21.1323_B     NaN              NaN
# C00819177         SB21.1323_B_B     NaN              NaN
# C00758672            SB21B.4853     NaN              NaN
# C00800201             500239876     NaN              NaN
# C00800201             500239894     NaN              NaN
# C00806752             SB17.4304     NaN              NaN
#
# [10 rows x 25 columns]
